# %%
import pandas as pd
from copy import deepcopy
import warnings
def ignore_warn(*args,**kwargs):
    pass
warnings.warn = ignore_warn

# %%
tele = pd.read_csv('tele.csv')
trans = pd.read_csv('trans.csv')
medical = pd.read_csv('medical.csv')
car = pd.read_csv('car.csv')
total_df_list = [tele,trans,medical,car]

# %%
for i,df in enumerate(total_df_list):
    df['model'] = i
    del df['Unnamed: 0']
    for column_name in df.columns:
        df[column_name] = df[column_name].fillna(df[column_name].mean())

# %%
df = pd.concat(total_df_list,axis=0)

# %%
replace = {'000004': '广东',
 '000016': '广东',
 '000020': '广东',
 '000021': '广东',
 '000022': '广东',
 '000030': '吉林',
 '000050': '广东',
 '000068': '广东',
 '000088': '广东',
 '000089': '广东',
 '000099': '广东',
 '000100': '广东',
 '000153': '安徽',
 '000338': '山东',
 '000403': '山西',
 '000413': '河北',
 '000423': '山东',
 '000429': '广东',
 '000507': '广东',
 '000513': '广东',
 '000518': '江苏',
 '000520': '湖北',
 '000534': '广东',
 '000536': '福建',
 '000538': '云南',
 '000547': '福建',
 '000548': '湖南',
 '000550': '江西',
 '000557': '宁夏',
 '000559': '浙江',
 '000561': '陕西',
 '000566': '海南',
 '000572': '海南',
 '000581': '江苏',
 '000582': '广西',
 '000586': '四川',
 '000590': '湖南',
 '000597': '辽宁',
 '000623': '吉林',
 '000625': '',
 '000636': '广东',
 '000650': '江西',
 '000661': '吉林',
 '000670': '湖北',
 '000700': '江苏',
 '000725': '北京',
 '000727': '江苏',
 '000733': '贵州',
 '000739': '浙江',
 '000755': '山西',
 '000756': '山东',
 '000760': '湖北',
 '000766': '吉林',
 '000788': '',
 '000790': '四川',
 '000800': '吉林',
 '000801': '四川',
 '000813': '新疆',
 '000828': '广东',
 '000868': '安徽',
 '000885': '河南',
 '000900': '湖南',
 '000905': '福建',
 '000908': '湖南',
 '000915': '山东',
 '000919': '江苏',
 '000927': '天津',
 '000931': '北京',
 '000938': '北京',
 '000951': '山东',
 '000952': '湖北',
 '000957': '山东',
 '000970': '北京',
 '000980': '浙江',
 '000981': '甘肃',
 '000989': '湖南',
 '000999': '广东',
 '001872': '广东',
 '001965': '天津',
 '002001': '浙江',
 '002007': '河南',
 '002017': '广东',
 '002020': '浙江',
 '002022': '上海',
 '002025': '贵州',
 '002030': '广东',
 '002038': '北京',
 '002040': '江苏',
 '002048': '浙江',
 '002049': '河北',
 '002079': '江苏',
 '002085': '浙江',
 '002089': '江苏',
 '002099': '浙江',
 '002101': '广东',
 '002102': '福建',
 '002107': '山东',
 '002115': '浙江',
 '002118': '吉林',
 '002120': '浙江',
 '002126': '浙江',
 '002137': '广东',
 '002138': '广东',
 '002151': '北京',
 '002156': '江苏',
 '002166': '广西',
 '002179': '河南',
 '002180': '广东',
 '002185': '甘肃',
 '002192': '广东',
 '002198': '广东',
 '002213': '广东',
 '002217': '福建',
 '002219': '甘肃',
 '002236': '浙江',
 '002239': '江苏',
 '002245': '江苏',
 '002252': '上海',
 '002262': '江苏',
 '002265': '云南',
 '002273': '浙江',
 '002275': '广西',
 '002283': '山东',
 '002284': '浙江',
 '002287': '西藏',
 '002289': '广东',
 '002294': '广东',
 '002308': '广东',
 '002313': '广东',
 '002317': '广东',
 '002320': '海南',
 '002328': '上海',
 '002332': '浙江',
 '002349': '江苏',
 '002351': '广东',
 '002352': '广东',
 '002355': '山东',
 '002357': '四川',
 '002363': '山东',
 '002365': '湖北',
 '002370': '浙江',
 '002376': '山东',
 '002383': '北京',
 '002384': '江苏',
 '002388': '广东',
 '002389': '浙江',
 '002390': '贵州',
 '002393': '天津',
 '002396': '福建',
 '002399': '广东',
 '002406': '河南',
 '002411': '陕西',
 '002412': '湖南',
 '002413': '江苏',
 '002415': '浙江',
 '002422': '四川',
 '002424': '贵州',
 '002433': '广东',
 '002434': '浙江',
 '002435': '江苏',
 '002437': '黑龙江',
 '002446': '广东',
 '002448': '河南',
 '002449': '广东',
 '002454': '上海',
 '002463': '江苏',
 '002468': '浙江',
 '002475': '广东',
 '002488': '浙江',
 '002492': '广东',
 '002506': '上海',
 '002510': '天津',
 '002512': '福建',
 '002519': '江苏',
 '002528': '广东',
 '002536': '河南',
 '002550': '江苏',
 '002562': '浙江',
 '002566': '吉林',
 '002579': '广东',
 '002581': '山东',
 '002587': '广东',
 '002590': '浙江',
 '002592': '广西',
 '002593': '福建',
 '002594': '广东',
 '002600': '广东',
 '002602': '浙江',
 '002603': '河北',
 '002625': '浙江',
 '002627': '湖北',
 '002644': '甘肃',
 '002653': '西藏',
 '002660': '广东',
 '002662': '北京',
 '002664': '浙江',
 '002675': '山东',
 '002680': '江苏',
 '002682': '福建',
 '002688': '内蒙古',
 '002693': '海南',
 '002703': '浙江',
 '002708': '江苏',
 '002711': '广东',
 '002715': '广东',
 '002725': '浙江',
 '002728': '广东',
 '002729': '福建',
 '002737': '黑龙江',
 '002745': '广东',
 '002750': '云南',
 '002755': '北京',
 '002765': '',
 '002766': '广东',
 '002773': '四川',
 '002782': '广东',
 '002800': '新疆',
 '002806': '广东',
 '002813': '广东',
 '002817': '安徽',
 '002821': '天津',
 '002826': '西藏',
 '002835': '广东',
 '002841': '广东',
 '002845': '广东',
 '002848': '湖南',
 '002859': '浙江',
 '002863': '浙江',
 '002864': '陕西',
 '002865': '海南',
 '002866': '江苏',
 '002868': '福建',
 '002869': '广东',
 '002873': '贵州',
 '002876': '广东',
 '002880': '广东',
 '002885': '广东',
 '002888': '广东',
 '002898': '广东',
 '002900': '黑龙江',
 '002902': '广东',
 '002906': '广东',
 '002907': '',
 '002913': '湖南',
 '002916': '广东',
 '002920': '广东',
 '002923': '广东',
 '002925': '福建',
 '002928': '贵州',
 '002930': '广东',
 '002932': '湖北',
 '002935': '四川',
 '002937': '浙江',
 '002938': '广东',
 '002940': '浙江',
 '002955': '北京',
 '002960': '河北',
 '002970': '广东',
 '002972': '广东',
 '200016': '广东',
 '200020': '广东',
 '200022': '广东',
 '200030': '吉林',
 '200045': '广东',
 '200152': '山东',
 '200413': '河北',
 '200429': '广东',
 '200468': '江苏',
 '200550': '江西',
 '200581': '江苏',
 '200625': '',
 '200725': '北京',
 '201872': '广东',
 '300006': '',
 '300009': '安徽',
 '300013': '江苏',
 '300016': '北京',
 '300026': '天津',
 '300028': '四川',
 '300039': '上海',
 '300065': '北京',
 '300079': '北京',
 '300083': '广东',
 '300086': '海南',
 '300088': '安徽',
 '300100': '浙江',
 '300108': '吉林',
 '300110': '山东',
 '300115': '广东',
 '300119': '天津',
 '300122': '',
 '300128': '江苏',
 '300136': '广东',
 '300142': '云南',
 '300147': '广东',
 '300158': '山西',
 '300176': '广东',
 '300181': '浙江',
 '300194': '',
 '300199': '广东',
 '300204': '北京',
 '300205': '湖北',
 '300211': '江苏',
 '300219': '广东',
 '300220': '湖北',
 '300223': '北京',
 '300227': '广东',
 '300232': '广东',
 '300233': '山东',
 '300239': '内蒙古',
 '300240': '江苏',
 '300241': '广东',
 '300254': '山西',
 '300255': '河北',
 '300256': '浙江',
 '300258': '江苏',
 '300267': '湖南',
 '300282': '北京',
 '300289': '北京',
 '300294': '江西',
 '300296': '北京',
 '300301': '广东',
 '300303': '广东',
 '300304': '江苏',
 '300308': '山东',
 '300322': '广东',
 '300323': '湖北',
 '300327': '上海',
 '300351': '浙江',
 '300357': '浙江',
 '300363': '',
 '300367': '北京',
 '300381': '广东',
 '300394': '江苏',
 '300397': '陕西',
 '300406': '北京',
 '300408': '广东',
 '300428': '河北',
 '300432': '四川',
 '300433': '湖南',
 '300434': '四川',
 '300436': '福建',
 '300439': '浙江',
 '300449': '北京',
 '300452': '安徽',
 '300456': '北京',
 '300458': '广东',
 '300460': '广东',
 '300463': '四川',
 '300479': '山东',
 '300482': '广东',
 '300485': '北京',
 '300497': '江西',
 '300501': '上海',
 '300507': '江苏',
 '300514': '广东',
 '300516': '湖北',
 '300519': '浙江',
 '300534': '甘肃',
 '300543': '广东',
 '300546': '广东',
 '300548': '浙江',
 '300555': '江苏',
 '300558': '浙江',
 '300563': '江苏',
 '300566': '浙江',
 '300570': '广东',
 '300573': '辽宁',
 '300580': '江苏',
 '300582': '浙江',
 '300583': '山东',
 '300584': '江苏',
 '300585': '江苏',
 '300601': '广东',
 '300602': '广东',
 '300615': '广东',
 '300620': '广东',
 '300623': '江苏',
 '300628': '福建',
 '300630': '海南',
 '300632': '福建',
 '300636': '江西',
 '300638': '广东',
 '300639': '广东',
 '300642': '上海',
 '300643': '浙江',
 '300647': '广东',
 '300652': '浙江',
 '300661': '北京',
 '300666': '浙江',
 '300679': '广东',
 '300680': '江苏',
 '300683': '湖北',
 '300685': '福建',
 '300686': '广东',
 '300689': '广东',
 '300695': '浙江',
 '300701': '河南',
 '300702': '浙江',
 '300705': '湖南',
 '300708': '江苏',
 '300709': '江苏',
 '300710': '浙江',
 '300723': '广东',
 '300726': '湖南',
 '300733': '四川',
 '300735': '广东',
 '300739': '广东',
 '300742': '江苏',
 '300743': '浙江',
 '300745': '广东',
 '300747': '湖北',
 '300752': '广东',
 '300762': '上海',
 '300782': '江苏',
 '300787': '江西',
 '300790': '广东',
 '300793': '广东',
 '300802': '上海',
 '300807': '河南',
 '300811': '广东',
 '600004': '广东',
 '600006': '湖北',
 '600009': '上海',
 '600012': '安徽',
 '600017': '山东',
 '600018': '上海',
 '600020': '河南',
 '600026': '上海',
 '600029': '广东',
 '600033': '福建',
 '600035': '湖北',
 '600056': '北京',
 '600060': '山东',
 '600062': '北京',
 '600066': '河南',
 '600074': '江苏',
 '600079': '湖北',
 '600080': '陕西',
 '600081': '上海',
 '600085': '北京',
 '600104': '上海',
 '600106': '',
 '600115': '上海',
 '600118': '北京',
 '600119': '上海',
 '600125': '辽宁',
 '600129': '',
 '600139': '四川',
 '600148': '吉林',
 '600151': '上海',
 '600161': '北京',
 '600166': '北京',
 '600171': '上海',
 '600178': '黑龙江',
 '600179': '黑龙江',
 '600183': '广东',
 '600190': '辽宁',
 '600195': '北京',
 '600196': '上海',
 '600201': '内蒙古',
 '600211': '西藏',
 '600213': '江苏',
 '600216': '浙江',
 '600221': '海南',
 '600222': '河南',
 '600227': '贵州',
 '600233': '辽宁',
 '600234': '山西',
 '600252': '广西',
 '600267': '浙江',
 '600269': '江西',
 '600270': '北京',
 '600271': '北京',
 '600276': '江苏',
 '600279': '',
 '600285': '河南',
 '600288': '北京',
 '600299': '北京',
 '600303': '辽宁',
 '600317': '辽宁',
 '600329': '天津',
 '600332': '广东',
 '600350': '山东',
 '600351': '山西',
 '600355': '湖北',
 '600360': '吉林',
 '600363': '江西',
 '600368': '广西',
 '600375': '安徽',
 '600377': '江苏',
 '600380': '广东',
 '600385': '山东',
 '600401': '江苏',
 '600405': '北京',
 '600418': '安徽',
 '600420': '上海',
 '600422': '云南',
 '600428': '广东',
 '600436': '福建',
 '600460': '浙江',
 '600479': '湖南',
 '600480': '河北',
 '600485': '北京',
 '600488': '天津',
 '600498': '湖北',
 '600501': '江苏',
 '600513': '江苏',
 '600518': '广东',
 '600521': '浙江',
 '600523': '贵州',
 '600525': '广东',
 '600530': '上海',
 '600535': '天津',
 '600548': '广东',
 '600552': '安徽',
 '600557': '江苏',
 '600561': '江西',
 '600562': '江苏',
 '600563': '福建',
 '600566': '湖北',
 '600568': '湖北',
 '600572': '浙江',
 '600575': '安徽',
 '600601': '上海',
 '600609': '辽宁',
 '600611': '上海',
 '600613': '上海',
 '600650': '上海',
 '600662': '上海',
 '600664': '黑龙江',
 '600666': '黑龙江',
 '600671': '浙江',
 '600676': '上海',
 '600686': '福建',
 '600698': '湖南',
 '600699': '浙江',
 '600703': '湖北',
 '600717': '天津',
 '600733': '北京',
 '600734': '福建',
 '600741': '上海',
 '600742': '吉林',
 '600745': '湖北',
 '600750': '江西',
 '600764': '北京',
 '600771': '青海',
 '600781': '河南',
 '600787': '天津',
 '600789': '山东',
 '600794': '江苏',
 '600798': '浙江',
 '600812': '河北',
 '600834': '上海',
 '600839': '四川',
 '600851': '上海',
 '600867': '吉林',
 '600870': '福建',
 '600888': '新疆',
 '600897': '福建',
 '600898': '山东',
 '600933': '浙江',
 '600960': '山东',
 '600980': '北京',
 '600990': '安徽',
 '601000': '河北',
 '601006': '山西',
 '601008': '江苏',
 '601018': '浙江',
 '601021': '上海',
 '601107': '四川',
 '601111': '北京',
 '601127': '',
 '601138': '广东',
 '601188': '黑龙江',
 '601228': '广东',
 '601238': '广东',
 '601298': '山东',
 '601326': '河北',
 '601333': '广东',
 '601518': '吉林',
 '601598': '北京',
 '601633': '河北',
 '601689': '浙江',
 '601777': '',
 '601799': '江苏',
 '601866': '上海',
 '601869': '湖北',
 '601872': '上海',
 '601880': '辽宁',
 '601919': '天津',
 '601965': '',
 '601975': '江苏',
 '603005': '江苏',
 '603006': '上海',
 '603009': '上海',
 '603013': '江苏',
 '603023': '黑龙江',
 '603032': '新疆',
 '603035': '江苏',
 '603037': '上海',
 '603056': '上海',
 '603066': '江苏',
 '603068': '上海',
 '603069': '海南',
 '603089': '浙江',
 '603115': '江苏',
 '603121': '上海',
 '603128': '上海',
 '603139': '陕西',
 '603158': '江苏',
 '603160': '广东',
 '603161': '江苏',
 '603166': '广西',
 '603167': '山东',
 '603168': '浙江',
 '603178': '浙江',
 '603179': '江苏',
 '603197': '上海',
 '603222': '浙江',
 '603223': '山东',
 '603228': '广东',
 '603229': '浙江',
 '603236': '上海',
 '603239': '浙江',
 '603267': '北京',
 '603286': '江苏',
 '603306': '福建',
 '603319': '湖南',
 '603329': '上海',
 '603335': '广东',
 '603351': '江苏',
 '603358': '江苏',
 '603367': '山东',
 '603380': '江苏',
 '603386': '广东',
 '603387': '江苏',
 '603390': '广东',
 '603456': '浙江',
 '603501': '上海',
 '603516': '北京',
 '603520': '浙江',
 '603535': '广东',
 '603538': '浙江',
 '603566': '河南',
 '603567': '黑龙江',
 '603586': '山东',
 '603590': '北京',
 '603596': '安徽',
 '603633': '上海',
 '603658': '河南',
 '603660': '江苏',
 '603669': '西藏',
 '603676': '西藏',
 '603707': '江苏',
 '603712': '天津',
 '603713': '上海',
 '603718': '上海',
 '603730': '上海',
 '603758': '',
 '603767': '浙江',
 '603768': '安徽',
 '603773': '江西',
 '603786': '上海',
 '603788': '浙江',
 '603809': '四川',
 '603811': '浙江',
 '603813': '广东',
 '603858': '山东',
 '603871': '北京',
 '603880': '江苏',
 '603885': '上海',
 '603890': '江苏',
 '603896': '浙江',
 '603920': '广东',
 '603922': '江苏',
 '603926': '浙江',
 '603963': '云南',
 '603967': '山东',
 '603976': '',
 '603982': '江苏',
 '603986': '北京',
 '603989': '湖南',
 '603996': '浙江',
 '603997': '浙江',
 '603998': '湖南',
 '688002': '山东',
 '688005': '浙江',
 '688007': '广东',
 '688008': '上海',
 '688011': '黑龙江',
 '688019': '上海',
 '688025': '广东',
 '688036': '广东',
 '688068': '北京',
 '688098': '上海',
 '688138': '广东',
 '688166': '江苏',
 '688288': '浙江',
 '688321': '广东',
 '688363': '山东',
 '688366': '上海',
 '688388': '广东',
 '688399': '江苏',
 '900903': '上海',
 '900904': '上海',
 '900914': '上海',
 '900917': '上海',
 '900941': '浙江',
 '900945': '海南',
 '900946': '湖南',
 '900952': '辽宁',
 '900953': '上海'}
location2num_dict = dict(zip(set(replace.values()),[i for i in range(31)]))

# %%
len(list(replace))
# Out:
# 713

# %%
df.astype('object')
# Out:
#     总资产利润率(%) 主营业务利润率(%) 总资产净利润率(%) 成本费用利润率(%) 营业利润率(%) 主营业务成本率(%) 销售净利率(%)  \
# 0       11.09      35.34      11.36      30.16    22.38      63.72    18.89
# 1        1.23       8.85       1.38       2.05     2.02      91.03     1.82
# 2        6.49      25.88       7.56       17.4    14.31      73.52    12.57
# 3        4.61      29.66       4.79      10.82     9.47      69.32     8.13
# 4        1.59      15.69       1.65       5.43     4.86      83.72     4.41
# ..        ...        ...        ...        ...      ...        ...      ...
# 131      5.11       5.56       4.98      14.17    13.79      92.18    15.04
# 132      0.21      17.01        0.2       0.49     0.26      81.59     0.46
# 133      3.31      21.49       3.75      15.54    14.91      77.17    15.58
# 134       3.3      29.62       3.32      19.67     16.5       69.6    14.37
# 135     -2.87       8.29      -2.86      -5.46    -5.58      88.21    -5.91
#
#     净资产收益率(%) 股本报酬率(%) 净资产报酬率(%)  ... 总资产周转天数(天) 流动资产周转率(次) 流动资产周转天数(天)  \
# 0       18.41    76.86     18.46  ...     448.95       0.77      349.47
# 1           6    35.33      5.84  ...     355.64       0.91      295.31
# 2        7.86    47.95      7.87  ...      448.8       0.81      332.35
# 3        6.16    24.51      6.15  ...     458.09       0.85      316.23
# 4        3.84    50.48      3.84  ...     720.58       1.51      179.21
# ..        ...      ...       ...  ...        ...        ...         ...
# 131      7.97    62.71      7.83  ...     815.22       0.75      358.99
# 132       0.3      0.9       0.3  ...     615.74       0.93      291.86
# 133      7.91    70.62      7.49  ...     1120.8       0.84      321.47
# 134      6.23    53.81      6.23  ...    1169.34       0.28      950.37
# 135     -6.11   -55.52     -6.13  ...     557.85       1.03      262.42
#
#     经营现金净流量对销售收入比率(%) 资产的经营现金流量回报率(%) 经营现金净流量与净利润的比率(%) 经营现金净流量对负债比率(%)  \
# 0                0.17             0.1              0.88            0.24
# 1                  -0              -0             -0.15              -0
# 2                0.04            0.02              0.32            0.12
# 3                0.01            0.01              0.17            0.03
# 4                0.11            0.04              2.46            0.07
# ..                ...             ...               ...             ...
# 131             -0.21           -0.07             -1.42           -0.21
# 132              0.11            0.05             23.51            0.16
# 133              0.27            0.06              1.74             0.1
# 134              0.19            0.04              1.33            0.09
# 135              0.08            0.04             -6.41            0.08
#
#     现金流量比率(%)    code model
# 0       24.51  300632     0
# 1       -0.24    2845     0
# 2       11.94  603115     0
# 3        3.12  300743     0
# 4       11.92      50     0
# ..        ...     ...   ...
# 131    -29.63  601238     3
# 132      17.4    2708     3
# 133     11.93  603035     3
# 134      9.35  300652     3
# 135       9.1     625     3
#
# [711 rows x 71 columns]

# %%
def code2location(x):
    code = '00000000'+str(int(x['code']))
    code = code[-6:]
    return location2num_dict[replace[code]]
df['location'] = df.apply(code2location,axis=1)

# %%
df.to_csv('input.csv')

# %%
df['type'] = df['model'] * 31 + df['location']

# %%
df

# %%
del df['model']
del df['location']
feature_list = list(df.columns)
feature_list.remove('type')

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(df[feature_list],df['type'])
model.predict(df[feature_list])

# %%
model.score(df[feature_list],df['type'])

# %%
from sklearn.cluster import KMeans
model = KMeans(124)
model.fit(df[feature_list])
model.predict(df[feature_list])

# %%
model.score(df[feature_list],df['type'])

# %%
from sklearn import preprocessing
X_scaled = preprocessing.scale(df[feature_list])

# %%
new_df = pd.DataFrame(X_scaled)
new_df.columns = df.columns[:-1]

# %%
new_df.corr()

# %%
import numpy as np
eig_value, eig_vector = np.linalg.eig(new_df.corr())
df2 = pd.DataFrame(eig_value.cumsum()/sum(eig_value))
df2.index = new_df.columns

# %%
df2.to_csv('eig_value_cumsum2.csv')

# %%
feature = new_df.columns[:44]

# %%
model = KMeans(124)

# %%
model.fit(new_df[feature])

# %%
model.predict(new_df[feature])

# %%
model.score(df[feature],df['type'])

# %%
from sklearn.metrics import jaccard_score,davies_bouldin_score

# %%
jaccard_score(model.predict(new_df[feature]),df['type'],average='macro')

# %%
davies_bouldin_score(new_df[feature],
                     model.predict(new_df[feature]))

# %%
from sklearn.cluster import AgglomerativeClustering
ac=AgglomerativeClustering(n_clusters=124)

# %%
predict = ac.fit_predict(new_df[feature])

# %%
jaccard_score(predict,df['type'],average='macro')

# %%
davies_bouldin_score(new_df[feature],
                     predict)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(df[feature],df['type'])

# %%
from sklearn import discriminant_analysis
lda=discriminant_analysis.LinearDiscriminantAnalysis()
lda.fit(train_x,train_y)
print('Coefficients:%s, intercept %s'%(lda.coef_,lda.intercept_))#输出权重向量和b
print('Score: %.2f' % lda.score(test_x, test_y))#测试集
print('Score: %.2f' % lda.score(train_x, train_y))#训练集

# %%
train_x, test_x, train_y, test_y = train_test_split(df[feature_list],df['type'])

# %%
from sklearn import discriminant_analysis
lda=discriminant_analysis.LinearDiscriminantAnalysis()
lda.fit(train_x,train_y)
print('Coefficients:%s, intercept %s'%(lda.coef_,lda.intercept_))#输出权重向量和b
print('Score: %.2f' % lda.score(test_x, test_y))#测试集
print('Score: %.2f' % lda.score(train_x, train_y))#训练集

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
def show_reason(predict,label):
    for i in range(np.unique(label).shape[0]):
        tp = ((predict == i) & (test_y == i)).sum()
        tn = ((predict != i) & (test_y != i)).sum()
        fn = ((predict != i) & (test_y == i)).sum()
        fp = ((predict == i) & (test_y != i)).sum()
        print('{}tp:{} tn:{},fn:{},fp:{}'.format(i,tp,tn,fn,fp))
    print(precision_score(predict,label,average='macro'))
    print(recall_score(predict,label,average='macro'))
    print(f1_score(predict,label,average='macro'))

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()
svm_model.fit(train_x,train_y)

# %%
print(svm_model.score(test_x,test_y))
show_reason(svm_model.predict(test_x), test_y)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=200,min_samples_split=5,random_state=11)
model.fit(train_x,train_y)
print(model.score(test_x,test_y))
show_reason(model.predict(test_x), test_y)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(train_x,train_y)
print(model.score(test_x,test_y))
show_reason(model.predict(test_x), test_y)

# %%
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=(200,))
model.fit(train_x,train_y)
print(model.score(test_x,test_y))
predict = model.predict(test_x)
show_reason(predict, test_y)
